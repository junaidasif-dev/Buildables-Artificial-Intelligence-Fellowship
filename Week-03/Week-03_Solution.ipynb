# %% [markdown]
# # **Questions From "1 Start Writing Prompts Like a Pro"**
#
#
# 1. **What is prompting?**
# ➡️ Prompting is the process of giving clear and specific instructions or inputs to a generative AI tool so it produces the desired output.
#
# 2. **In the following prompt, which part describes the primary task?**
# *Prompt: “Explain how car batteries work using non-technical language that someone without any mechanical knowledge could understand and interpret.”*
# ➡️ The primary task is: “Explain how car batteries work.”
#
# 3. **When you are using a gen AI tool to create a healthy three-course menu that requires a certain number of calories, which prompting element will ensure the menu is more practical?**
# ➡️ Adding constraints (specific calorie requirement) makes the menu more practical.
#
# 4. **Prompting with audio to receive a visual representation is called what?**
# ➡️ That’s called multimodal prompting.
#
# 5. **What does a human-in-the-loop approach to prompting emphasize?**
# ➡️ It emphasizes human oversight, feedback, and iterative refinement to guide the AI toward accurate and useful results.
#
# 6. **When the initial prompt "Create a dataset" is too broad, what should you do to refine it?**
# ➡️ You should add context, details, and constraints (e.g., type of dataset, size, format, domain) to make the request more specific and actionable.

# %% [markdown]
# # **Questions from "2 Design prompts for everyday work tasks"**
#
# ### Exercise: Try It Yourself ❗
# 1. Write down your **to-do list** for today or this week.
# - Finalize my resume for job applications
# - Research more about LangChain for my AI project
# - Write a LinkedIn post about AI automation
# - Prepare slides for my MLSA session
# - Reply to pending emails
# 2. Pick **one task** where AI could help.
#    - Write a LinkedIn post about AI automation
# 3. Open your AI tool and **give it this prompt**:
#    - *Draft a short, engaging LinkedIn post about the importance of AI automation in saving time and improving efficiency, written in a professional yet approachable tone.*
# 4. Review, edit, and use the result ✅
#
# ### Exercise: Try It Yourself ❗
# 1. Think of an **email you need to write** (e.g., to your team, customers, or a client).
# - Email I need to write:
# A follow-up email to a client who attended a demo of my AI chatbot service.
# 2. Use the **prompt framework**:
#    - Persona: Who are you?
#    - Context: What’s happening?
#    - Task: What do you want the email to do?
#    - Specificity: Add tone, format, details.
#
# ➡️ Prompt framework:
# - Persona: I am an AI developer offering chatbot/automation solutions.
# - Context: I gave the client a demo last week, and I want to follow up.
# - Task: Write a polite follow-up email reminding them about next steps and offering to answer questions.
# - Specificity: Professional, clear, friendly tone. Keep it short.
# 3. Ask your AI tool to **draft the email**.
# *You are an AI developer. Draft a professional, friendly follow-up email to a client who attended a chatbot demo last week. Thank them for their time, remind them about next steps, and offer to answer any questions. Keep the email concise and polite.*
# 4. Then, **iterate**:
#    - Change the tone (formal → casual, professional → fun).
#    - Adjust the audience.
#
# Iteration examples:
#
# - Change tone (formal → casual):
# *Hi [Client Name], just checking in after last week’s chatbot demo. Hope you found it useful! Happy to answer questions or chat about next steps whenever you’re ready.*
#
# - Adjust audience (client → team):
# *Hey team, thanks for joining the demo session last week. Let’s connect tomorrow to discuss how we can apply these chatbot features to our workflow.*
#
# ### Exercise: Try It Yourself ❗
# **Practice Tone & Style Prompting**
# 1. Pick a short text you’ve written (an email, a report, or a social post).
# - Short text (original draft):
# *Excited to share that I just completed a workshop on AI automation. Learned a lot about n8n and LangChain!*
#
# 2. Rewrite your prompt to **specify tone and style**.
#    - *Make this LinkedIn post sound inspirational, like a TED speaker motivating professionals*
#
# 3. Run it through your AI tool.
# - AI-generated version (Inspirational/TED style):
# *Thrilled to share a milestone—completing a workshop on AI automation! Tools like n8n and LangChain aren’t just technologies; they’re stepping stones to building smarter, more impactful solutions. The future is here, and it’s waiting for us to shape it.*
#
# 4. Iterate: Ask for a new version in a **different tone** (funny, formal, academic, casual).
# - Funny:
# *Just wrapped up an AI automation workshop. My brain now runs on n8n and LangChain—send help (or more coffee)! ☕🤖*
#
# - Formal/Professional:
# *I am pleased to announce that I have successfully completed a workshop on AI automation, with a focus on n8n and LangChain. This experience has enhanced my technical expertise and professional growth.*
#
# - Casual:
# *Super pumped—I just finished an AI automation workshop! Learned some cool stuff about n8n and LangChain that I can’t wait to try out.*
#
# 5. Compare the results — which version feels most effective for your audience?
# - Inspirational → Best for audience looking for motivation/professional growth.
# - Funny → Best for friends or a relaxed online community.
# - Formal → Best for resume, portfolio, or official announcement.
# - Casual → Best for peers or social media where you want to stay approachable.
#
# ###  Exercises : Try It Yourself ❗
#
# ### Exercise 1: Icebreakers
#
# Write a prompt asking AI to generate **3 creative icebreakers** for a new teammate who loves basketball and photography.
#
# *Generate 3 creative and friendly icebreakers I can use to welcome a new teammate who loves basketball and photography. Keep them fun, casual, and engaging.*
#
# ### Exercise 2: Product Launch
#
# Imagine you’re launching a **new mobile fitness app** (it can be any product).
# Write a prompt to:
#
# * Define a **6-month launch timeline**.
# * Suggest **3 pre-launch buzz ideas**.
#
# *You are a marketing strategist. Create a 6-month launch timeline for a new mobile fitness app. Include key milestones, campaigns, and engagement strategies. Also, suggest 3 creative pre-launch buzz ideas to build excitement before launch.*
#
# ### Exercise 3: Global Audience Twist
#
# Take your product launch prompt and **iterate** by asking the AI to adjust the ideas for a **global audience**.
#
# *Revise the 6-month launch timeline and pre-launch buzz ideas for the mobile fitness app so they appeal to a global audience. Consider cultural differences, diverse social media platforms, and inclusive messaging.*
#
# ### Exercises: Try It Yourself ❗
#
# ### Exercise 1: Project Tracker
#
# Prompt AI to create a **project tracker** with columns: Task, Owner, Deadline, Status.
# Add constraints: Each owner should have no more than 2 active tasks.
#
# *Create a project tracker table with columns: Task, Owner, Deadline, and Status. Make sure each owner has no more than 2 active tasks assigned at a time.*
#
# ### Exercise 2: Event Schedule
#
# You’re planning a **3-day conference**. Ask AI to generate a schedule with:
#
# * Columns: Day, Session Title, Speaker, Time.
# * Constraint: No speaker should have more than 1 session per day.
#
# *Generate a 3-day conference schedule in table format with columns: Day, Session Title, Speaker, and Time. Ensure that no speaker has more than 1 session per day.*
#
# ### Exercise 3: Team Availability
#
# Write a prompt to generate a **vacation tracker** for 8 employees.
#
# * Columns: Employee, Vacation Start, Vacation End.
# * Constraint: At least 5 employees must be available at all times.
#
# *Create a vacation tracker for 8 employees in table format with columns: Employee, Vacation Start, and Vacation End. Apply the rule that at least 5 employees must be available (not on vacation) at all times.*
#
# ### ✅ Reflection Question
#
# How could you use AI to **organize recurring tasks** (like meetings, deadlines, or resources) at your workplace?
#
# I could use AI to organize recurring tasks by automating reminders, tracking deadlines, and generating schedules. For example:
# - AI could auto-generate a weekly meeting agenda based on past notes.
# - It could send reminders to team members about upcoming deadlines.
# - AI can maintain a resource tracker (like who booked a meeting room or borrowed equipment) and alert when conflicts arise.
# - With integrations (e.g., calendars, project trackers), AI can reschedule tasks automatically if priorities shift.
# - This way, I save time on routine planning and focus more on the actual work.
#
# ### Exercises: Try It Yourself ❗
#
# ### Exercise 1: Speaker-based Minutes
#
# Take a sample transcript (or your last meeting notes) and prompt AI:
#
# **Meeting Transcript (short sample)**
# - Participants: Alice (Project Manager), Bob (Developer), Sarah (Designer)
# - Alice: Thanks for joining. We need to finalize the website redesign timeline. The client expects delivery by end of next month. Action item: confirm final timeline.
# - Bob: Development is on track, but I’ll need the updated wireframes from Sarah by next Monday. Action item: Sarah to deliver updated wireframes.
# - Sarah: I can finish the wireframes by Friday. Also, I think we should update the color palette for a fresher look. Action item: propose new palette.
# - Alice: Great. Let’s also schedule a client check-in meeting next Wednesday. Action item: Alice to send invite.
#
# ```
# Summarize the meeting into minutes by speaker.
# Add 2–3 bullet points per speaker, and mark action items clearly.
# ```
# **Alice (Project Manager)**
# - Highlighted the need to finalize the website redesign timeline.
# - Mentioned client expects delivery by end of next month.
# - Action Item: Confirm final timeline.
# - Action Item: Send invite for client check-in meeting next Wednesday.
#
# **Bob (Developer)**
# - Reported development is on track.
# - Needs updated wireframes to proceed.
# - Action Item: Waiting for Sarah’s wireframes by Monday.
#
# **Sarah (Designer)**
# - Committed to finishing updated wireframes by Friday.
# - Suggested updating the color palette for a fresher look.
# - Action Item: Deliver updated wireframes by Friday.
# - Action Item: Propose new color palette.
#
# ### Exercise 2: Action-Focused Notes
#
# Use this prompt:
#
# ```
# Create meeting minutes that focus only on action items.
# Format each entry as: Action Item, Responsible Person, Deadline.
# ```
# 1. Action Item: Confirm final timeline → Alice → End of next month
# 2. Action Item: Deliver updated wireframes → Sarah → Friday
# 3. Action Item: Propose new color palette → Sarah → Friday
# 4. Action Item: Send client check-in invite → Alice → Before Wednesday
# 5. Action Item: Proceed with development after receiving wireframes → Bob → Next Monday
#
# ### Exercise 3: Thematic Notes
#
# Try refining for themes:
#
# ```
# Group meeting minutes into sections based on topics discussed.
# For each section, summarize key decisions, and list assigned action items.
# ```
# 1. Project Timeline
# - Key Decision: Finalize website redesign timeline by end of next month.
# - Action Item: Alice to confirm final timeline.
#
# 2. Design Updates
# - Key Decision: Updated wireframes required to keep development on track.
# - Key Decision: Consider refreshing the color palette.
# - Action Items:
#   - Sarah to deliver updated wireframes by Friday.
#   - Sarah to propose new color palette.
#
# 3. Client Communication
# - Key Decision: Hold client check-in meeting next Wednesday.
# - Action Item: Alice to send meeting invite.
#
# ### Exercises: Try It Yourself ❗
#
# ### Exercise 1: Outline Summary
#
# Take a long article or report. Prompt AI:
#
# **Report Topic:**
# *The Impact of Remote Work on Productivity and Employee Well-being*
#
# ```
# Summarize this document into a bulleted outline of no more than 10 points.
# ```
# - Remote work adoption has accelerated since 2020.
# - Productivity levels vary across industries.
# - Flexibility increases employee satisfaction.
# - Communication challenges remain significant.
# - Use of collaboration tools has surged.
# - Work-life balance is improving for many employees.
# - Some workers report feelings of isolation.
# - Employers save costs on office space.
# - Hybrid models are becoming the norm.
# - Long-term effects on career growth remain unclear.
#
# ### Exercise 2: Audience Summary
#
# Try this with the same text:
#
# ```
# Summarize this document as if explaining it to a high school student.
# ```
# Since 2020, a lot more people are working from home. Many say they enjoy the flexibility and feel happier, but some miss seeing their coworkers and feel lonely. Companies are saving money on office space, and new apps like Zoom and Teams make teamwork easier. The big question now is whether people will keep working from home, go back to the office, or do a mix of both.
#
# ### Exercise 3: Comparative Summary
#
# Use:
#
# ```
# Summarize this report in two versions:
# 1. Executive summary for leadership.
# 2. Simplified version for frontline employees.
# ```
# 1. Executive Summary for Leadership:
# - Remote work has improved employee satisfaction and reduced facility costs.
# - Productivity results are mixed; depends on industry and job role.
# - Communication and collaboration challenges persist, requiring ongoing investment in digital tools.
# - Hybrid work is the emerging long-term model.
# - Leadership should focus on balancing flexibility with maintaining team cohesion and career development opportunities.
#
# 2. Simplified Version for Frontline Employees:
# Working from home has both upsides and downsides. Many people enjoy the flexibility and time saved, but it can also feel lonely. Tools like Zoom and Teams help us stay connected, and in the future, most companies will likely use a mix of home and office work.
#
# ### ✅ Reflection Question 💡
#
# How could tailoring summaries to **different audiences** (executives, clients, students) improve understanding and decision-making in your work?
#
# Tailoring summaries to different audiences makes information clearer, more relevant, and more actionable:
# - Executives need concise, high-level insights with key metrics and decisions → helps them act quickly.
# - Clients need simplified, benefit-focused language → builds trust and keeps them engaged.
# - Students or learners need easy-to-grasp explanations with examples → improves understanding and retention.
#
# By matching the tone, depth, and detail of a summary to the audience, you reduce confusion, highlight what matters most to them, and ultimately support better decisions and stronger communication.

# %% [markdown]
# # **Questions from "3 Use AI as a creative or expert partner"**
#
# ### 📝 Questions for Reflection
#
# 1. How is prompt chaining similar to solving a jigsaw puzzle?
# Because both involve breaking a big, complex problem into smaller, manageable pieces and then combining them to form the complete picture. Each “prompt” is like a puzzle piece that contributes to the final solution.
#
# 2. What’s the main difference between iteration and chaining?
# - Iteration = refining the same prompt multiple times to improve the output.
# - Chaining = breaking a complex task into a sequence of smaller prompts, where each output feeds into the next step.
#
# 3. Why might prompt chaining be more effective than asking AI one big question?
# Because one big question can overwhelm the model, leading to vague or unfocused results. Chaining keeps the task structured, guides the model step by step, and ensures higher accuracy and clarity.
#
# 4. How can the context window of an AI model affect your chaining strategy?
# The context window limits how much information the model can “remember” at once. If your chain is too long, earlier details may get lost. To manage this, you might need to:
#     - Summarize intermediate outputs.
#     - Use external storage (notes, databases) to carry context forward.
#     - Keep each step concise.
#
# ##  Exercises : Try It Yourself ❗
#
# ### Exercise 1: Email Catch-Up
#
# Imagine you were away from work for a week. Create a **prompt chain** that does the following:
#
# 1. Summarizes all your emails.
# 2. Highlights urgent tasks.
# 3. Suggests solutions for the most critical issue.
#
# - Summarize all emails I received this past week in a bulleted list by topic. Keep it short and organized.
# - From the summary above, identify urgent tasks that require immediate attention. List them with deadlines and responsible people.
# - From the urgent tasks, identify the most critical issue and suggest 2–3 practical solutions I can take right away.
#
# ### Exercise 2: Research Assistant
#
# You’re writing a research paper. Design a chain of prompts to:
#
# 1. Generate an outline of your paper.
# 2. Suggest three key studies you should cite.
# 3. Draft a short introduction based on the outline and studies.
#
# - Create a clear outline for a research paper on AI limitations. Include sections and sub-sections.
# - Suggest three recent and relevant academic studies I should cite in my paper on AI limitations. Include author names, year, and a one-sentence summary of each.
# - Using the outline and the three studies, draft a short, 2-paragraph introduction that clearly states the problem, background, and importance of the research.
#
# ### Exercise 3: Business Idea Pitch
#
# Pretend you want to launch a new mobile app. Build a prompt chain that:
#
# 1. Creates a one-sentence pitch.
# 2. Expands it into a short paragraph describing the target audience.
# 3. Generates a three-slide pitch deck outline for investors.
#
# - Create a one-sentence pitch for a new mobile app idea focused on restaurant process automation.
# - Expand the one-sentence pitch into a short paragraph that explains who the target audience is, their needs, and how this app solves their problem.
# - Create a simple three-slide pitch deck outline for investors based on the app idea. Slides: Problem, Solution, Market Opportunity.
#
# ### Exercise: Try It Yourself ❗
# 1. Pick a **creative or abstract problem** (e.g., designing a campaign, brainstorming product features).
# 2. Write a prompt asking AI to explore **multiple solutions** and evaluate them.
#    - Example: *“Propose three marketing strategies for a new app launch. Evaluate each for cost, reach, and impact.”*
# 3. Review the output and iterate to refine (e.g., focus on one path or add constraints).
#
# ### Problem Chosen:
# - Brainstorming features for a habit-tracking mobile app.
#
# ### Prompt to AI:
# *Propose three innovative features for a new habit-tracking app. Evaluate each feature in terms of user engagement, development cost, and long-term impact.*
#
# ### Sample Output (AI might give):
#
# **Feature 1: Gamification with Streak Rewards**
# - **User Engagement:** High — users stay motivated by earning badges and maintaining streaks.
# - **Development Cost:** Medium — requires backend tracking and UI for rewards.
# - **Long-term Impact:** Strong — encourages consistent use, but risk of burnout if rewards feel repetitive.
#
# **Feature 2: AI-Powered Habit Suggestions**
# - **User Engagement:** Medium-High — personalized suggestions increase relevance.
# - **Development Cost:** High — needs machine learning models and data.
# - **Long-term Impact:** Strong — app evolves with user behavior, keeping it useful over time.
#
# **Feature 3: Social Accountability Groups**
# - **User Engagement:** Very High — peer support drives consistency.
# - **Development Cost:** Medium — chat or community system needed.
# - **Long-term Impact:** Strong — fosters community, but moderation is required.
#
# ### Iteration Example
#
# **New refined prompt:**
# *Focus on the ‘Social Accountability Groups’ feature. Suggest ways to keep the community safe and positive, while minimizing moderation costs.*
#
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: CoT for Decision-Making
# Write a prompt for a work-related decision (e.g., prioritizing tasks, choosing vendors). Ask AI to explain its reasoning step-by-step.
# Example: *“Help me choose between two software vendors. Explain your reasoning for each step.”*
#
# ### Prompt (Vendor Selection)
#
# Help me choose between Vendor A and Vendor B for [service].
#
# 1. List 4 decision criteria and why each matters.
# 2. For each vendor, give a concise score (1–5) for each criterion and a one-sentence justification.
# 3. Show a total score and recommend one vendor.
# 4. Provide a short, numbered explanation of the top 3 reasons for your recommendation.
# 5. Suggest 2 practical next steps.
#
# **Format:**
# - Table for scores
# - Numbered list for reasons and next steps
#
# #### Exercise 2: ToT for Creative Brainstorming
# Write a prompt for a creative task (e.g., campaign ideas, product features). Ask AI to propose multiple solutions and evaluate them.
# Example: *“Suggest three themes for a company retreat. Evaluate each for engagement and cost.”*
#
# ### Prompt (Creative Problem-Solving)
#
# Propose three distinct solutions for [creative problem]. For each solution:
# - Short description (one line)
# - 3 strengths
# - 3 risks/weaknesses
# - Estimated cost level (low/medium/high)
# - Time to implement (short/medium/long)
# - One concrete example of how it would look in practice
#
# Finally, rank the three by expected impact and give a one-line reason for the ranking.
#
# #### Exercise 3: Combine CoT and ToT
# Write a prompt that uses ToT to explore options and CoT to refine the best one.
# Example: *“Propose three product launch ideas, evaluate them, then provide a step-by-step plan for the best one.”*
#
# ### Prompt (Strategy Evaluation)
#
# 1. Propose four distinct strategies for [goal].
# 2. Evaluate each on **cost, reach, and speed** (scale: 1–5) and show the results in a **table**.
# 3. Choose the best strategy and provide a concise, **numbered step-by-step implementation plan** (each step should include: objective, owner role, deadline).
#
# **Format the output:**
# - Table for evaluation
# - Numbered list for implementation plan
#
# ### ✅ Reflection Question 💡
# How could CoT and ToT prompting help you **solve complex problems** or **spark creativity** in your workplace?
#
# - **Decompose complexity:** CoT (stepwise reasoning) breaks decisions into traceable steps so you can audit and trust the result.
# - **Explore more possibilities:** ToT (branching / multiple-thought paths) forces the model to propose diverse options rather than one shallow idea.
# - **Better trade-offs:** Combining them lets you generate many options (ToT) and then rigorously justify and refine one (CoT), improving quality of final plans.
# - **Faster iteration:** Clear, numbered steps and evaluation metrics make it easy to tweak assumptions and re-run specific parts of the chain.
# - **Human + AI collaboration:** Structured outputs (scores, short justifications, step plans) make it easy for humans to review, challenge, and approve — ideal for human-in-the-loop workflows.
#
# ### Exercise: Try It Yourself ❗
# 1. Pick a **multi-step project** (e.g., event planning, report writing).
# 2. Write a prompt to generate an initial output (e.g., an outline or plan).
# 3. Chain a second prompt to expand a specific part of the output.
# 4. Chain a third prompt to create an activity or visual based on the expanded output.
#    - Example: *“Create a project plan for a team event, expand the agenda into a detailed schedule, then suggest a themed icebreaker activity.”*
#
# ### Multi-Step Project Chosen: Organizing a Training Workshop
#
# **Step 1 – Initial Prompt (outline/plan)**
# Create a high-level project plan for a one-day training workshop on *"AI for Beginners."*
# Include sections: **Objectives, Audience, Agenda (with 3 sessions), Resources, and Timeline.**
#
# **Step 2 – Chain Prompt (expand part of the output)**
# Expand the **"Agenda"** section into a detailed schedule with times, session titles, activities, and breaks.
# Format as a table with columns: **Time | Session | Activity | Outcome.**
#
# **Step 3 – Chain Prompt (create an activity/visual)**
# Based on the morning session (*"Introduction to AI"*), design a simple **interactive group activity.**
# - Describe the **rules, materials needed, and expected learning outcome.**
# - Suggest a **visual (diagram or chart)** that could be used to explain AI basics in this activity.
#
# #### Exercise: Try It Yourself ❗
# 1. Choose a task where reasoning matters (e.g., budgeting, scheduling).
# 2. Write a prompt asking AI to explain its reasoning step-by-step.
#    - Example: *“Plan a $5,000 team retreat and explain your reasoning for each expense.”*
# 3. Review the reasoning and refine the prompt if needed (e.g., add constraints).
#
# # Step 1 – Task Chosen: Scheduling a 2-day team offsite
#
# # Step 2 – Prompt:
#
# Plan a 2-day team offsite for 12 people with a $3,000 budget.
# Explain your reasoning step-by-step for venue, food, activities, and transport.
#
# # Step 3 – Output (AI Reasoning):
#
# **Venue – $1,200**
# Step 1: Prioritize a nearby conference center with lodging to save transport costs.
# Step 2: Choose mid-range venue offering meeting rooms + 1-night accommodation at $100/person.
# Step 3: Total = $1,200.
#
# **Food – $600**
# Step 1: Budget $25 per person per meal × 2 meals/day × 2 days = $1,200.
# Step 2: Reduce cost by selecting buffet/catering at $50 per person per day.
# Step 3: Total = $600.
#
# **Activities – $800**
# Step 1: Include one team-building activity (outdoor challenge/game) at $400.
# Step 2: Add workshop materials + facilitator = $400.
# Step 3: Total = $800.
#
# **Transport – $400**
# Step 1: Choose shared vans instead of individual rides.
# Step 2: 3 vans × $200/day = $600, but split to 2 vans × $200/day = $400.
# Step 3: Total = $400.
#
# **Grand Total = $3,000**
#
# # Step 4 – Refined Prompt (added constraints):
#
# Revise the plan so that food options include vegetarian meals, and no activity exceeds $300.
# Explain reasoning step-by-step.
#
# #### Exercise: Try It Yourself ❗
# 1. Pick a **creative task** (e.g., campaign ideas, visual design).
# 2. Write a prompt asking AI to propose three distinct solutions and evaluate them.
#    - Example: *“Suggest three themes for a product launch event, evaluate each for cost and appeal, and recommend one.”*
# 3. Follow up by refining the recommended option.
#
# # Step 1 – Creative Task Chosen: Designing a social media campaign for a new eco-friendly water bottle.
#
# # Step 2 – Prompt:
#
# Suggest three distinct social media campaign ideas for launching an eco-friendly water bottle.
# Evaluate each for cost, reach, and appeal, then recommend the best one.
#
# # Step 3 – Output (AI Response):
#
# **Idea 1 – #RefillRevolution Challenge**
# - **Cost:** Medium (video editing, influencer micro-partnerships).
# - **Reach:** High (user-generated content + TikTok/Instagram Reels).
# - **Appeal:** Very strong, taps into community challenges.
#
# **Idea 2 – Minimalist Aesthetic Campaign**
# - **Cost:** Low (static designs, in-house graphics).
# - **Reach:** Medium (appeals to niche design/eco-conscious audience).
# - **Appeal:** Moderate, may not excite mass audience.
#
# **Idea 3 – Eco-Impact Calculator**
# - **Cost:** High (developing an interactive tool for website + ads).
# - **Reach:** Medium (requires users to engage with the tool).
# - **Appeal:** Strong for data-driven and sustainability-focused consumers.
#
# **Recommendation:** Idea 1 – *#RefillRevolution Challenge* because of its viral potential, high reach, and strong emotional appeal at a moderate cost.
#
# # Step 4 – Refined Prompt (Follow-Up):
#
# Refine the *#RefillRevolution Challenge* into a detailed **2-week campaign plan.**
# Include content schedule, sample posts, and engagement tactics.
#
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: Build a Project Step-by-Step
# 1. Pick a multi-step project (e.g., marketing campaign, event planning).
# 2. Chain three prompts: outline, expand a section, create an activity/visual.
#    - Example: *“Outline a team training program, expand one module, suggest an interactive exercise.”*
#
# # Question / Step 1 (Prompt):
#
# Create a high-level project plan for a one-day team training program titled *"AI for Product Teams."*
# Include: **Objectives, Audience, Agenda (3 sessions), Resources, and Timeline.**
#
# ---
#
# # Output (Step 1 — Outline):
#
# **Objectives:** Introduce AI concepts for product managers, teach simple hands-on prototyping, align team on applying AI in product roadmaps.
#
# **Audience:** Product managers, PM-adjacent designers, product-focused engineers (12–18 people).
#
# **Agenda (3 sessions):**
# - **Session 1 — AI Fundamentals (60 min)**
# - **Session 2 — Hands-on Prototyping Workshop (120 min)**
# - **Session 3 — Roadmapping & Integration (60 min)**
#
# **Resources:** Projector, laptops (BYO), sample datasets, prototype templates, facilitator guide.
#
# **Timeline:** 9:00–5:00 day: registration 9:00, Session 1 9:30, break, Session 2 11:00–13:00, lunch 13:00–14:00, Session 3 14:00–15:00, wrap & next steps 15:00–16:00.
#
# ---
#
# # Question / Step 2 (Prompt):
#
# Expand the *"Session 2 — Hands-on Prototyping Workshop"* into a detailed schedule with times, activities, and learning outcomes.
# Format: **Time | Activity | Details | Outcome.**
#
# ---
#
# # Output (Step 2 — Expanded Session 2):
#
# | Time       | Activity               | Details                                                                 | Outcome                   |
# |------------|------------------------|-------------------------------------------------------------------------|---------------------------|
# | 11:00–11:15 | Intro & teams          | Divide into 3 cross-functional teams; brief on dataset and challenge    | Teams ready and aligned   |
# | 11:15–11:45 | Problem framing        | Identify user problem to solve with AI; sketch success metric           | Clear problem statements  |
# | 11:45–12:30 | Rapid prototype        | Build UI/flow mockup and define inputs/outputs                          | Prototype storyboard      |
# | 12:30–12:55 | Model mock & demo script | Draft how AI will respond (pseudo-API), prepare demo script             | Demo-ready prototype      |
# | 12:55–13:00 | Quick share            | 3-minute lightning share per team                                       | Feedback for iteration    |
#
# ---
#
# # Question / Step 3 (Prompt):
#
# Design an **interactive group activity** for the morning session *"Introduction to AI":*
# - Rules
# - Materials
# - Timebox
# - Expected learning outcome
# Also suggest a **simple visual** to explain AI inference (describe the visual).
#
# ---
#
# # Output (Step 3 — Activity & Visual):
#
# **Activity — "Human-inference Relay"**
# - **Rules:** Split into 4 small teams. Each team receives an input card (user request).
#   - Round 1: Team A writes features needed to answer the request.
#   - Round 2: Team B selects data sources.
#   - Round 3: Team C picks the model behavior (explainable, cautious, brief).
#   - Round 4: Team D crafts the final response.
#   - Rotate roles so everyone experiences each step.
#
# - **Materials:** Input cards, sticky notes, markers, timer.
# - **Timebox:** 30 minutes (5 min intro + 20 min rounds + 5 min debrief).
# - **Expected Learning Outcome:** Understand the stages of AI output: input → features/data → model behavior → output; appreciate human decisions at each stage.
#
# **Visual (description):**
# A simple 4-box left→right flowchart:
# **User Input → Data & Features → Model Behavior → AI Output**
# - Each box annotated with one guiding question (e.g., *“What data?”* *“How should model behave?”*).
#
#
# #### Exercise 2: CoT for Clarity
# 1. Choose a task requiring logic (e.g., budgeting, scheduling).
# 2. Prompt AI to explain its reasoning step-by-step.
#    - Example: *“Allocate a $2,000 budget for a team event. Explain your reasoning.”*
#
# # Question / Step (prompt)
#
# Allocate a $2,000 budget for a one-day team offsite for 15 people.
# Explain your reasoning step-by-step for each expense category.
#
# ---
#
# # Output (Step-by-step reasoning & allocation)
#
# **Venue — $600**
# - **Step 1:** Target a local community center or mid-range meeting room to minimize travel costs.
# - **Step 2:** Estimate room + basic AV at $600 for the day (fixed booking fee).
# - **Step 3:** Allocation = $600.
#
# **Food & Catering — $600**
# - **Step 1:** Plan 2 meals + snacks per person. Set per-person meal budget: breakfast $15, lunch $20, snacks $5 → per-person total = 15 + 20 + 5 = 40.
# - **Step 2:** Calculate for 15 people: 15 × 40 = (10×40) + (5×40) = 400 + 200 = 600.
# - **Step 3:** Allocation = $600.
#
# **Activities & Facilitator — $400**
# - **Step 1:** Book an external facilitator for a team-building workshop at around $300–$400.
# - **Step 2:** Include materials and small activity supplies = $100.
# - **Step 3:** Allocation = $400.
#
# **Transport — $200**
# - **Step 1:** Use 2 shared vans or a shuttle service instead of individual rides to save cost.
# - **Step 2:** Estimate $200 total for shuttle round trips.
# - **Step 3:** Allocation = $200.
#
# **Materials & Contingency — $200**
# - **Step 1:** Reserve ~10% of budget for printed materials, extras, or last-minute needs.
# - **Step 2:** Allocation = $200.
#
# ---
#
# ## Totals (step-by-step sum)
# - Venue $600 + Food $600 = $1,200.
# - $1,200 + Activities $400 = $1,600.
# - $1,600 + Transport $200 = $1,800.
# - $1,800 + Contingency $200 = $2,000.
#
# **Grand Total = $2,000**
#
# ---
#
# ## Allocation Table
#
# | Category                   | Allocation |
# |---------------------------:|-----------:|
# | Venue                      | $600       |
# | Food & Catering            | $600       |
# | Activities & Facilitator   | $400       |
# | Transport                  | $200       |
# | Materials & Contingency    | $200       |
# | **Grand Total**            | **$2,000** |
#
# #### Exercise 3: ToT for Creativity
# 1. Pick a creative task (e.g., branding, content ideas).
# 2. Prompt AI to propose three solutions and evaluate them.
#    - Example: *“Suggest three social media campaign ideas. Evaluate each for engagement.”*
#
# ### Question / Step (prompt):
#
# Suggest three distinct social media campaign ideas for launching an eco-friendly water bottle. Evaluate each for Engagement, Cost, and Feasibility, then recommend one.
#
# ### Output (Three ideas + evaluation):
#
# **Idea A — #RefillRevolution Challenge**
#
# - **Description:** User-generated short videos showing creative refill moments and tagging friends.
# - **Engagement:** High — viral potential through challenges.
# - **Cost:** Medium — influencer seeding and content moderation.
# - **Feasibility:** High — easy to execute on TikTok/Instagram.
# - **Strengths:** Organic reach, community-driven.
# - **Weaknesses:** Requires moderation and good incentives.
#
# **Idea B — Minimalist Brand Storytelling**
#
# - **Description:** Clean photo/video series highlighting design, materials, and lifecycle.
# - **Engagement:** Medium — appeals to niche design-conscious audience.
# - **Cost:** Low — in-house photography & reposts.
# - **Feasibility:** High — straightforward to produce.
# - **Strengths:** Low cost, brand-building.
# - **Weaknesses:** Slower reach growth.
#
# **Idea C — Eco-Impact Calculator Campaign**
#
# - **Description:** Interactive tool that shows environmental impact saved per bottle; promoted with demo videos.
# - **Engagement:** Medium — educational, shareable for certain audiences.
# - **Cost:** High — tool development + promotion.
# - **Feasibility:** Medium — needs web dev and tracking.
# - **Strengths:** Credibility and stickiness.
# - **Weaknesses:** Higher upfront cost.
#
# #### Exercise 4: Combine CoT and ToT
# 1. Use ToT to explore options for a project.
# 2. Use CoT to refine the best option with detailed reasoning.
#    - Example: *“Propose three event formats, evaluate them, then plan the best one with step-by-step reasoning.”*
#
# ### Question / Step A (ToT prompt):
#
# Propose three event formats for launching a new productivity app. For each: one-line description, primary audience, and 3 evaluation criteria (Cost, Reach, Engagement).
#
# ---
#
# ### Output (Step A — three formats):
#
# **In-person Demo Night** — Live product demos + Q&A at a local venue — **Audience:** local professionals — **Criteria:** Cost (high), Reach (low-medium), Engagement (high).
#
# **Interactive Livestream Launch** — Live streamed launch with live polls and mini workshops — **Audience:** remote users globally — **Criteria:** Cost (medium), Reach (high), Engagement (medium).
#
# **Pop-up Experience Tour** — Short pop-up booths in coworking spaces across cities — **Audience:** on-the-ground early adopters — **Criteria:** Cost (high), Reach (medium), Engagement (very high).
#
# ---
#
# ### Question / Step B (ToT→Evaluate prompt):
#
# Evaluate the three formats across Cost/Reach/Engagement using a 1–5 scale (5 = best). Show a table and short pros/cons.
#
# ---
#
# ### Output (Step B — evaluation table + pros/cons):
#
# | Format                    | Cost (1–5) | Reach (1–5) | Engagement (1–5) | Notes                                                           |
# |--------------------------:|-----------:|------------:|-----------------:|-----------------------------------------------------------------|
# | In-person Demo Night      | 2          | 3           | 5                | Great engagement, limited scale; venue costs high.              |
# | Interactive Livestream    | 4          | 5           | 4                | Broad reach, moderate cost, needs strong moderation.            |
# | Pop-up Experience Tour    | 2          | 3           | 5                | High local impact, logistics-heavy and costly.                  |
#
# **Pros/Cons (one-line each):**
#
# - **In-person:** +deep demos, −limited audience.
# - **Livestream:** +global reach, −less personal.
# - **Pop-up:** +memorable experiences, −complex operations.
#
# ---
#
# ### Question / Step C (CoT prompt):
#
# Choose the best format from above and provide a step-by-step implementation plan (each step: objective, owner role, deadline, one-line reasoning).
#
# ---
#
# ### Output (Step C — chosen format & step-by-step plan):
#
# **Chosen Format:** Interactive Livestream Launch (best balance of cost, reach, and engagement).
#
# 1. **Define launch script & segments** — *Owner:* Product Marketing — *Deadline:* 4 weeks before launch — *Reasoning:* A clear script ensures smooth flow and planned engagement hooks.
# 2. **Book hosts & guest speakers** — *Owner:* Community Manager — *Deadline:* 3 weeks before — *Reasoning:* Hosts drive engagement and credibility.
# 3. **Build landing page & registration** — *Owner:* Web Dev — *Deadline:* 3 weeks before — *Reasoning:* Captures audience data and boosts attendance.
# 4. **Produce promotional content & influencer seeding** — *Owner:* Social Media Lead — *Deadline:* 2 weeks before — *Reasoning:* Drives awareness and sign-ups.
# 5. **Dry run & technical test** — *Owner:* Engineering + Ops — *Deadline:* 3 days before — *Reasoning:* Prevents tech issues and rehearses transitions.
# 6. **Livestream & engagement moderation** — *Owner:* Community + Product — *Deadline:* Launch day — *Reasoning:* Live moderation ensures high-quality interaction.
# 7. **Post-event follow-up & metrics** — *Owner:* Analytics + Sales — *Deadline:* 2 days after — *Reasoning:* Measure success and convert attendees.
#
# ### ✅ Reflection Question 💡
# How could prompt chaining help you **simplify a complex project** or **improve collaboration** in your workplace?
#
# Prompt chaining could simplify a complex project by breaking it into smaller, manageable steps—like first outlining goals, then expanding tasks, and finally creating visuals or activities. This structured flow prevents overwhelm and ensures clarity at each stage. For collaboration, chaining helps align the team: each prompt can focus on a different aspect (e.g., one for project scope, another for task assignments, another for timelines), so everyone works with consistent, AI-generated guidance. This keeps communication clear, reduces misalignment, and speeds up decision-making.
#
# #### Exercise: Try It Yourself ❗
# 1. Pick a **time-sensitive task** (e.g., email, proposal, or presentation).
# 2. Write a prompt asking AI to draft an outline or initial version.
#    - Example: *“Draft a professional email inviting clients to a product demo. Include date, time, and purpose.”*
# 3. Refine the output to match your style or add specific details.
#
# Step 1 – Time-Sensitive Task Chosen: Prepare a short proposal for a new internal AI workshop.
#
# Step 2 – Prompt:
#
# Draft a 1-page proposal for an internal AI workshop for employees.
# Include purpose, date, duration, key topics, and expected outcomes.
# Make it professional but concise.
#
# Step 3 – Initial Output (AI Draft):
# Proposal: AI Workshop for Employees
#
# Purpose: Equip employees with foundational knowledge of AI tools for productivity and innovation.
#
# Date & Duration: March 25, 2025 | 3 hours.
#
# Key Topics:
#
# Introduction to AI & workplace applications
#
# Hands-on demo of productivity tools
#
# Best practices & ethical use of AI
#
# Expected Outcomes:
#
# Improved understanding of AI basics
#
# Confidence in applying AI for daily tasks
#
# Roadmap for continued learning
#
# Step 4 – Refined Version (Matching Style + Details):
# Internal Proposal: AI Workshop for Teams
#
# Purpose: To give our teams a practical introduction to AI tools and show how they can improve daily workflows.
#
# Date & Duration: March 25, 2025 | 10:00 AM – 1:00 PM (3 hours).
#
# Agenda:
#
# AI Basics in Plain Language – what it is and why it matters
#
# Practical Demo – using AI for emails, reports, and scheduling
#
# Do’s & Don’ts – responsible and ethical use at work
#
# Outcomes:
#
# Team members leave with hands-on practice
#
# Clear ideas on how to use AI for their own tasks
#
# Shared resources for continued self-learning
#
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: Direct Generation
# 1. Pick a **task** (e.g., writing, planning, or design).
# 2. Write a meta-prompt to generate a prompt for it.
#    - Example: *“Generate a prompt to write a customer thank-you email for a retail store.”*
#
# *Generate a prompt to write a project update email for a client, summarizing completed milestones, upcoming tasks, and expected delivery timelines.*
#
#
# #### Exercise 2: Template Request
# 1. Choose a **structured task** (e.g., event plan, report outline).
# 2. Write a meta-prompt for a prompt template.
#    - Example: *“Create a template for a prompt to organize a team-building event.”*
#
# *Create a template for a prompt to design a weekly meal plan that includes breakfast, lunch, and dinner, with healthy and budget-friendly options.*
#
# #### Exercise 3: Prompt Refinement
# 1. Take an **existing prompt** with suboptimal results.
# 2. Write a meta-prompt to improve its tone, clarity, or specificity.
#    - Example: *“How can I improve this prompt for a social media post to be more engaging? [Attach prompt]”*
#
# **Original Prompt (suboptimal):**
# *Write a LinkedIn post about AI tools.*
#
# **Meta-Prompt for Refinement:**
# *How can I improve this prompt for a LinkedIn post so it highlights key AI tools, uses a professional yet engaging tone, and encourages readers to comment or share?*
#
# #### Exercise 4: Meta-Prompt Chaining
# 1. Choose a **complex task** (e.g., proposal, campaign).
# 2. Write a meta-prompt for one part, then chain another for the next part.
#    - Example: *“Generate a prompt for a campaign slogan, then one for a campaign timeline.”*
#
# **Step 1 Meta-Prompt:**
# *Generate a prompt to create three campaign slogans for an eco-friendly product.*
#
# **Step 2 Meta-Prompt:**
# *Generate a prompt to design a campaign timeline with weekly activities (social media, events, ads) for the eco-friendly product.*
#
# ### ✅ Reflection Question 💡
# How could meta-prompting help you **craft better prompts** or **improve AI outputs** for your specific work tasks?
#
# Meta-prompting can help me craft better prompts by making them more structured, goal-oriented, and specific. It allows me to refine vague requests into clear instructions, which improves the quality of AI outputs for tasks like writing proposals, generating reports, or creating campaigns.
#
# ### Exercise: Try It Yourself ❗
# 1. Choose a **scenario** (e.g., client meeting, performance review).
# 2. Write a prompt for AgentSim to role-play, specifying the persona, conversation types, and stop phrase.
#    - Example: *“Act as a client in a sales meeting. Support discussions on product benefits and pricing. End when I say ‘DONE.’ Provide feedback afterward.”*
# 3. Test the simulation and refine the prompt for clarity or detail.
#
# **Scenario Chosen:** Performance Review
#
# **Prompt for AgentSim:**
# *Act as a manager conducting a performance review. Provide constructive feedback on my recent work, highlight strengths, and suggest areas for improvement. Keep the tone professional but supportive. End the role-play when I say ‘DONE.’ Afterward, provide feedback on how I responded during the review.*
#
# **Refined Prompt (after testing):**
# *Act as a manager in a performance review. Give detailed feedback on my performance across three areas: task completion, teamwork, and communication. Use a balanced tone with praise and improvement suggestions. Ask follow-up questions to encourage reflection. End the role-play when I say ‘DONE.’ Afterward, summarize key takeaways and provide feedback on my responses.*
#
# ### Exercise: Try It Yourself ❗
# 1. Choose a **work output** (e.g., report, presentation, or plan).
# 2. Write a prompt for AgentX to provide feedback, specifying the expertise and focus areas.
#    - Example: *“Act as a project management consultant. Review my project plan and suggest improvements for timeline and resource allocation.”*
# 3. Use the feedback to improve your work and refine the prompt if needed.
#
# **Work Output Chosen:** Report
#
# **Prompt for AgentX:**
# *Act as a business analyst. Review my report on market trends and provide feedback on three focus areas: clarity of insights, data accuracy, and actionable recommendations. Suggest specific improvements where needed.*
#
# **Refined Prompt (after feedback):**
# *Act as a senior business analyst with expertise in market research. Review my market trends report and evaluate it across four dimensions: clarity of insights, data accuracy, depth of analysis, and practicality of recommendations. Provide constructive feedback with examples, and suggest actionable revisions to strengthen the report.*
#
# ### ✅ Reflection Question 💡
#
# AI agents like AgentSim can help me practice skills by simulating real scenarios such as client meetings, negotiations, or interviews, giving me a safe space to refine communication and decision-making.
# AgentX can improve my work outputs by acting as an expert reviewer, offering constructive feedback on reports, presentations, or plans, which helps me identify gaps, refine ideas, and produce higher-quality results.
# Together, they support both skill development and output improvement in my role.
#
# ### Exercises: Try It Yourself ❗
#
# #### Exercise 1: Create a Communication Prompt
# 1. Choose a **communication task** (e.g., email, announcement).
# 2. Write a prompt and save two versions (e.g., formal vs. casual).
#    - Example: *“Write a customer email for a product recall (v1: formal, v2: empathetic).”*
#
# **Task:** Announcement email for product update
#
# - **Version 1 (Formal):**
# “Write a professional email announcing a product update. Use a formal tone, highlight new features, and thank customers for their continued trust.”
#
# - **Version 2 (Casual):**
# “Write a friendly email announcing a product update. Use an engaging tone, highlight exciting new features, and invite customers to try them out.”
#
#
# #### Exercise 2: Create a Content Prompt
# 1. Pick a **content task** (e.g., FAQ, social media post).
# 2. Write a prompt and version it for different audiences.
#    - Example: *“Create 5 FAQs for consumers (v1) and businesses (v2) based on this product.”*
#
# **Task:** Social media post for product launch
#
# - **Version 1 (For Consumers):**
# “Create an engaging Instagram post announcing a new product launch. Highlight ease of use, benefits, and why customers should try it.”
#
# - **Version 2 (For Businesses):**
# “Create a LinkedIn post announcing a new product launch. Focus on ROI, scalability, and how it helps businesses achieve efficiency.”
#
#
# #### Exercise 3: Use Meta-Prompting
# 1. Write a meta-prompt to generate or refine a prompt for your library.
#    - Example: *“Generate a prompt for a project status report with a clear, professional tone.”*
#
# **Meta-Prompt:**
# “Generate a prompt for writing a weekly project status report that is concise, professional, and easy for stakeholders to understand.”
#
#
# #### Exercise 4: Organize Your Library
# 1. Create a **spreadsheet or document** with 3–5 prompts, categorized by use case.
# 2. Add notes on tone, audience, and effectiveness.
#
# **Prompt Library (Sample Table):**
#
# | Prompt Description                     | Use Case              | Tone      | Audience        | Notes on Effectiveness |
# |----------------------------------------|-----------------------|-----------|-----------------|-------------------------|
# | Product update email                   | Communication         | Formal    | Customers       | Works well for official updates |
# | Product update email                   | Communication         | Casual    | Customers       | Increases engagement    |
# | Product launch social post             | Content               | Engaging  | Consumers       | Great for Instagram reach |
# | Product launch LinkedIn post           | Content               | Professional | Businesses   | Builds credibility      |
# | Weekly project status report (meta)    | Internal Reporting    | Professional | Stakeholders  | Keeps updates clear and structured |
#
#
# ### ✅ Reflection Question 💡
# How could a prompt library help you **streamline repetitive tasks** or **improve AI outputs** in your work?
#
# A prompt library could help me streamline repetitive tasks by providing ready-to-use templates for emails, reports, and posts. It would also improve AI outputs by keeping prompts consistent in tone, audience focus, and structure, ensuring more reliable and high-quality results across different work scenarios.

# %% [markdown]
# ## Recap of Notebook 1
# - Introduces a clear 5-step prompting framework (Task, Format, Context, References, Evaluate & Iterate) and applies it with concrete examples (e.g., startup ideas).
# - Explains zero/one/few-shot prompting, using personas and structured formats, and provides a practical checklist and prompt template.
# - Emphasizes “Always Be Iterating” with strategies: break complex tasks, rephrase/analogies, and add constraints to sharpen outputs.
# - Covers multimodal prompting (images, documents, audio), specifics for image prompts, and responsible AI use (policies, privacy, bias, human-in-the-loop).
# - Shares ways to reduce hallucinations (fact-check, verification tools, clearer prompts) and ends with a short quiz to reinforce learning.
#
# ## Recap of Notebook 2
# - The 5-step prompting framework, zero/one/few-shot prompting, and practical prompt design with personas, formats, and structured outputs.
# - Emphasizes iteration strategies (ABI): break tasks into steps, rephrase or use analogous tasks, and add constraints to sharpen results.
# - Introduces multimodal prompting (images, documents, audio) with tips for image prompts and combining media with text.
# - Covers responsible AI use: policies, privacy, bias awareness, human-in-the-loop, and techniques to reduce hallucinations through verification and clearer prompts.
# - Includes short quizzes/reflections and concrete prompt templates/checklists to apply the concepts.
#
# ## Recap of Notebook 3
# - Explores using AI as a creative or expert collaborator across workflows, shifting from single prompts to multi-step collaboration.
# - Covers roles you can assign (brainstorming partner, critic, planner, teacher) and how to alternate them to improve breadth and depth.
# - Shows practical prompting patterns: idea → expand → critique → revise; plus checklists, rubrics, and “red team” prompts to stress-test outputs.
# - Emphasizes structure and reliability with JSON/outlined formats, constraints, and self-evaluation loops to reduce errors and drift.
# - Includes use cases (writing, product/design, research planning) and guidelines for responsible, verifiable outputs with human judgment in the loop.

# %% [markdown]
# # **Report – Joni Eats Chatbot**
# This section answers the guideline’s questions (1–6) in narrative form for reporting and submission.
#
# ## 1) Use Case, Target Users, Benefits, Limitations
# Use case: A customer-facing cafe assistant for Joni Eats. The bot answers menu questions, dietary info (vegan/halal/gluten‑free), opening hours, location, specials, wait times, and simple ordering guidance.
#
# - Target users: Walk‑in customers, regulars, and first‑time visitors who want quick answers without waiting for staff during rush hours.
# - Expected benefits: Faster service, fewer repetitive questions for staff, consistent information, and better discovery of items (e.g., seasonal specials).
# - Limitations: Not a payment system, no real‑time inventory unless integrated, may not reflect last‑second menu changes, and should not give medical or legal advice.
#
# ## 2) Justification
# A chatbot is well‑suited because cafe inquiries are short, frequent, and repetitive. Compared to browsing a website/menu PDF, chat supports quick follow‑ups (e.g., “any nut‑free desserts?”) and clarifications. Versus human staff, the bot can answer 24/7 and reduce queue pressure while keeping tone consistent. It will perform retrieval‑augmented Q&A from a curated knowledge base (menu, policies, specials) and follow a conversation flow for greetings, clarifying questions, and goodbyes.
#
# ## 3) Groq Model Selection
# Primary model: llama-3.1-8b-instant on Groq for fast, low‑latency chat. Rationale:
# - Size/speed: 8B is cost‑effective and responsive for real‑time interactions; upgrade path to 70B exists for tougher reasoning.
# - Language: Good English fluency; multilingual support acceptable for basic hospitality queries.
# - Latency: Groq’s inference speed improves user experience during live chat.
#
# ## 4) Conversation Flow (with samples)
# Flow:
# 1. Greeting → “Hi, welcome to Joni Eats! How can I help?”
# 2. Understand intent → Identify if the user asks about menu, hours, location, dietary needs, or specials.
# 3. Retrieve context → Pull top KB snippets relevant to the query.
# 4. Respond → Provide concise, friendly answer; list 3–5 options if appropriate.
# 5. Clarify → Offer follow‑ups: “Want vegan or gluten‑free options?”
# 6. Goodbye → Close politely or handoff to staff if needed.
#
# Sample inputs/responses:
# - Q: “Do you have vegan lunch options under $12?”
#   A: “Yes—try our Vegan Power Bowl and Roasted Veggie Wrap (both under $12). Would you like a protein add‑on?”
# - Q: “What time do you open on Saturdays?”
#   A: “We open at 12:00 PM and close at 2:00 AM.”
#
# ## 5) Prompting Technique
# Technique: Few‑shot prompting (examples from the corpus’s CHAT_PATTERNS section) plus zero‑shot fallback. The system prompt defines the Joni Eats persona and scope. Structured, bulleted outputs keep answers skimmable. The prompt asks the model to only answer cafe‑related questions and to gracefully decline out‑of‑scope queries while steering back to menu/hours/specials.
#
# ## 6) Frontend
# A Streamlit UI makes the bot easy to try: chat interface, settings (model, temperature, top‑k), and an expander that shows retrieved snippets for transparency. This supports quick feedback from staff and customers before deeper integrations (ordering, inventory).

# %% [markdown]
# ## **Let's try my ChatBot - Joni Eats**
# https://jonieats-chatbot.streamlit.app/
